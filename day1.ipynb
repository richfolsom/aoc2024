# %%
import pandas as pd

# %%
# !pip install pandas
# Out:
# ...
#   Using cached pandas-2.2.3-cp312-cp312-win_amd64.whl.metadata (19 kB)
# ...
#   Using cached pytz-2024.2-py2.py3-none-any.whl.metadata (22 kB)
# ...
#   Using cached tzdata-2024.2-py2.py3-none-any.whl.metadata (1.4 kB)
# ...
# Using cached pandas-2.2.3-cp312-cp312-win_amd64.whl (11.5 MB)
# ...
#    ---------------------------------------- 0.0/12.6 MB ? eta -:--:--
#    ---------- ----------------------------- 3.4/12.6 MB 18.3 MB/s eta 0:00:01
#    ------------------------- -------------- 7.9/12.6 MB 19.5 MB/s eta 0:00:01
#    ----------------------------------- ---- 11.0/12.6 MB 19.6 MB/s eta 0:00:01
#    ---------------------------------------- 12.6/12.6 MB 16.8 MB/s eta 0:00:00
# Using cached pytz-2024.2-py2.py3-none-any.whl (508 kB)
# Using cached tzdata-2024.2-py2.py3-none-any.whl (346 kB)
# ...

# %%
df = pd.read_csv('data.csv')

# %%
df
# Out:
#      list1  list2
# 0    64430  75582
# 1    87936  20843
# 2    98310  72035
# 3    98142  69076
# 4    73170  50561
# ..     ...    ...
# 995  25533  96431
# 996  68777  15175
# 997  47390  75651
# 998  94550  80760
# 999  61539  20843
#
# [1000 rows x 2 columns]

# %%
list1 = list(df.list1.sort_values())

# %%
list2 = list(df.list2.sort_values())

# %%
list2
# Out:
# [10245,
#  10253,
#  10379,
#  10468,
#  10687,
#  10953,
#  11004,
#  11156,
#  11262,
#  11404,
#  11445,
#  11599,
#  11797,
#  11853,
#  12152,
#  12291,
#  12344,
#  12352,
#  12373,
#  12607,
#  12924,
#  13148,
#  13336,
#  13352,
#  13466,
#  13525,
#  13782,
#  14075,
#  14080,
#  14227,
#  14399,
#  14982,
#  15090,
#  15099,
#  15175,
#  15295,
#  15301,
#  15314,
#  15435,
#  15539,
#  16037,
#  16081,
#  16199,
#  16319,
#  16738,
#  16864,
#  17008,
#  17116,
#  17473,
#  17588,
#  17766,
#  17827,
#  17962,
#  18036,
#  18088,
#  18405,
#  18409,
#  18411,
#  18855,
#  19059,
#  19177,
#  19198,
#  19198,
#  19198,
#  19198,
#  19198,
#  19198,
#  19198,
#  19323,
#  19442,
#  19941,
#  20125,
#  20147,
#  20329,
#  20415,
#  20452,
#  20540,
#  20540,
#  20540,
#  20540,
#  20540,
#  20540,
#  20540,
#  20540,
#  20540,
#  20540,
#  20540,
#  20540,
#  20540,
#  20540,
#  20540,
#  20540,
#  20540,
#  20540,
#  20540,
#  20540,
#  20649,
#  20716,
#  20716,
#  20716,
# ...

# %%
df = pd.DataFrame()

# %%
df['list1'] = list1

# %%
df['list2'] = list2

# %%
df['diff'] = abs(df['list1'] - df['list2'])

# %%
df['diff'].sum()
# Out:
# np.int64(2057374)

# %%
df
# Out:
#      list1  list2  diff
# 0    10054  10245   191
# 1    10323  10253    70
# 2    10415  10379    36
# 3    10576  10468   108
# 4    10746  10687    59
# ..     ...    ...   ...
# 995  99380  98749   631
# 996  99686  98910   776
# 997  99764  99026   738
# 998  99803  99039   764
# 999  99883  99213   670
#
# [1000 rows x 3 columns]

# %%
df[df['diff']==0]
# Out:
#      list1  list2  diff
# 116  20843  20843     0
# 563  60748  60748     0
# 776  79589  79589     0
# 788  80760  80760     0
# 920  92252  92252     0
